# %%
import requests
from sqlalchemy import create_engine
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
heartFailure_file = "heartFailure.csv"
heartFailure_df = pd.read_csv(heartFailure_file,low_memory = False)
heartFailure_df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
heartFailure_df.dropna()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
heartFailure_df["id"] = heartFailure_df.index + 1

# %%
heartFailure_df = heartFailure_df.drop(['time'], axis=1)

# %%
heartFailure_df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
heartFailure_df = heartFailure_df[["age","anaemia","creatinine_phosphokinase","diabetes","ejection_fraction","high_blood_pressure","platelets","serum_creatinine","serum_sodium","sex","smoking","DEATH_EVENT","id"]].copy()
heartFailure_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  DEATH_EVENT  id
# 0        0            1   1
# 1        0            1   2
# ...

# %%
heartFailure_cols =["age","anaemia","creatinine_phosphokinase","diabetes","ejection_fraction","high_blood_pressure","platelets","serum_creatinine","serum_sodium","sex","DEATH_EVENT","id"]
heartFailure_transformed= heartFailure_df[heartFailure_cols].copy()


heartFailure_transformed = heartFailure_transformed.rename(columns={"age":"age",
                                                                    "anaemia":"anaemia",
                                                                    "creatinine_phosphokinase":"creatinine_phosphokinase",
                                                                    "diabetes":"diabetes",
                                                                    "ejection_fraction":"ejection_fraction",
                                                                    "high_blood_pressure":"high_blood_pressure",
                                                                    "platelets":"platelets",
                                                                    "serum_creatinine":"serum_creatinine",
                                                                    "serum_sodium":"serum_sodium",
                                                                    "sex":"sex",
                                                                    "smoking":"smoking",
                                                                    "DEATH_EVENT":"death_event",
                                                                    "id":"id"})

heartFailure_transformed.set_index("id", inplace=True)

heartFailure_transformed.head()
# Out:
#      age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# id
# 1   75.0        0                       582         0                 20
# 2   55.0        0                      7861         0                 38
# 3   65.0        0                       146         0                 20
# 4   50.0        1                       111         0                 20
# 5   65.0        1                       160         1                 20
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# id
# 1                     1  265000.00               1.9           130    1
# 2                     0  263358.03               1.1           136    1
# 3                     0  162000.00               1.3           129    1
# 4                     0  210000.00               1.9           137    1
# 5                     0  327000.00               2.7           116    0
#
#     death_event
# id
# 1             1
# 2             1
# 3             1
# ...

# %%
#connection_string = "postgres:Predator@1702@localhost:5432/mb_db"
#engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
#engine.table_names()

# %%
#heartFailure_transformed.to_sql(name='heartfailure', con=engine, if_exists='append', index=True)

# %%
connection_string = "root:3B_dataanalytics@mypostgresdb.cd98u61l7amw.ap-southeast-2.rds.amazonaws.com:5432/postgres"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['heartfailure']

# %%
heartFailure_transformed.to_sql(name='heartfailure', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "heartfailure_pkey"
# DETAIL:  Key (id)=(1) already exists.
#
#
# The above exception was the direct cause of the following exception:
# ...
